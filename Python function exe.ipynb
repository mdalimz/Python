# %% [markdown]
# # Python splitfields() Method
# The splitfields() method is a user-defined method written in Python that splits any kind of data into a list of fields using a delimiter.

# %%
#Syntax: string.splitfields(delimiter)

# %% [markdown]
# Return Value: The splitfields() method returns a list of fields that were separated by the specified delimiter. If no delimiter is specified, the method splits the string using whitespace characters. If the string is empty, the method returns an empty list.

# %%
#1: Using splitfields() with the wrong type of arguments
num = 23 # same for str
fields = num.splitfields(",")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16612\1055565138.py in <module>
#       1 #1: Using splitfields() with the wrong type of arguments
#       2 num = 23 # same for str
# ----> 3 fields = num.splitfields(",")
#
# AttributeError: 'int' object has no attribute 'splitfields'

# %%
class MyString(): 
	def splitfields(self,sep=None): 
		if sep is None: 
			return self.split() 
		else: 
			return self.split(sep) 

# Splitting a string into fields using whitespace as delimiter 
str1 = "The quick brown fox"
fields1 = MyString(str1).splitfields() 
print(fields1) 


# Splitting a string into fields using a specific delimiter 
str2 = "apple,banana,orange"
fields2 = MyString(str2).splitfields(",") 
print(fields2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16612\2949766531.py in <module>
# ----> 1 class MyString("str"):
#       2         def splitfields(self,sep=None):
#       3                 if sep is None:
#       4                         return self.split()
#       5                 else:
#
# TypeError: str() argument 2 must be str, not tuple

# %%
#3: Using splitfields() with a List
